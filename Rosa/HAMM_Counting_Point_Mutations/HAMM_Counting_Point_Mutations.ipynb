# %%
#Hamming distance is number of differences between two equal len seqs

# %%
dna1 = "..."
dna2 = "..."

hamm = 0
for dna1_char, dna2_char in zip(dna1, dna2):
    if dna1_char != dna2_char:
        hamm +=1
print(hamm)
# Out:
# 517
