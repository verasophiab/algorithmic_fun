# %%
dna = open('3.Complementing_a_Strand_of_DNA/rosalind_revc.txt', 'r').read()
repl_dict = {'A':'T', 'T':'A', 'G':'C', 'C':'G'}
reverse_compl = ""
for char in dna:
    reverse_compl = repl_dict[char] + reverse_compl
print(reverse_compl)
# Out:
# ...
